# %%
# dictionary qustions

# %%
#1
person={"name":"anandhu","age":18}
print(person["name"])
print(person["age"])
# Out:
# anandhu
# 18

# %%
#2
student={"name":"rahul","class":10,"mark":95}
print(student["name"])
# Out:
# rahul

# %%
#3
marks = {"maths":90,"science":85,"english":88}
print(marks.keys())
# Out:
# dict_keys(['maths', 'science', 'english'])

# %%
#4
d={"name":"anu"}
d["city"]="kochi"
print(d)
# Out:
# {'name': 'anu', 'city': 'kochi'}

# %%
#5
d={"a":10,"b":20}
d["b"]=50
print(d)
# Out:
# {'a': 10, 'b': 50}

# %%
#6
d={"name":"akhil","age":21}
d.pop("age")
print(d)
# Out:
# {'name': 'akhil'}

# %%
#7
employee={"name":"arun","salary":50000,"city":"delhi"}
print(employee.values())
# Out:
# dict_values(['arun', 50000, 'delhi'])

# %%
#8
d={"name":"ravi","salary":40000}
print("salary"in d)
# Out:
# True

# %%
#9
d1={"a":1}
d2={"b":2}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2}

# %%
#10
d={"a":1,"b":2,"c":3}
print(len(d))
# Out:
# 3
