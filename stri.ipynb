# %%
x=6

# %%
x
# Out:
# 6

# %%
x=3
print(x)
# Out:
# 3

# %%
x=12
print(x)
# Out:
# 12

# %%
a=1
b=2
sum=a+b
print(sum)
# Out:
# 3

# %%
a=2
b=4
sum=a+b
print(sum)
# Out:
# 6

# %%
#string word
my_first_string='algebra'
print(my_first_string)
# Out:
# algebra

# %%
#entire phrase
phrase='statics sits at the heart of machine learning'
print(phrase)
# Out:
# statics sits at the heart of machine learning

# %%
#entire phrase
phrase='statistics sits at the heart of machine learning'
print(phrase)
# Out:
# statistics sits at the heart of machine learning

# %%
hash='#'
print (hash)
# Out:
# #

# %%
type(hash)
# Out:
# str

# %%
#we can simply declear a string
'deep learning'
'deep learning'
# Out:
# 'deep learning'

# %%
print('linear algebra')
print('calculus')
print('use\n to print a new line')
print('\n')
print('see what\n I mean?')
# Out:
# linear algebra
# calculus
# use
#  to print a new line
#
#
# see what
#  I mean?

# %%
algo='regres sion'
len(algo)
# Out:
# 11

# %%
#assin string as a string
string = 'principal components ananlysis!'

# %%
#print the object
print(string)
# Out:
# principal components ananlysis!

# %%
print(string[0])
print(string[1])
# Out:
# p
# r

# %%
#show first element (in the case a letter)
print(string[5])
# Out:
# i

# %%
print(string[15])
# Out:
# n

# %%
len(string)
# Out:
# 31

# %%
#grab the element at the index -1, which is the last element
print(string[28])
# Out:
# i

# %%
print(string[-1])
# Out:
# !

# %%
print(string[-2])
# Out:
# s

# %%
print(string[-2])
# Out:
# s

# %%
print(string[-29])
# Out:
# i

# %%
dy='fan'

# %%
print(dy[0])
# Out:
# f

# %%
print(dy[-3])
# Out:
# f

# %%
#grab everything past the first term all the way to the leangth of s which is len(s)
print(string)
print(string[:13])
# Out:
# principal components ananlysis!
# principal com

# %%
string[13]
# Out:
# 'p'

# %%
string[12]
# Out:
# 'm'

# %%
#grab everything starting from ndex 10 till index 18
print(string[10:])
# Out:
# components ananlysis!

# %%
print(string)
# Out:
# principal components ananlysis!

# %%
print(string[3:5])
# Out:
# nc

# %%
print(string[2:4])
# Out:
# in

# %%
#everything
print(string[:1])
print(string)
# Out:
# p
# principal components ananlysis!

# %%
#last letter (one index behind 0 so it loops back around)
string[-29]
# Out:
# 'i'

# %%
print(string)
string[-10:10]
# Out:
# principal components ananlysis!
# ''

# %%
letters='wubba'
letters*3
# Out:
# 'wubbawubbawubba'

# %%
1#store your name in a string and print it in  uppercase
name='anandhu'
print(name.upper())
# Out:
# ANANDHU

# %%
#store your name in a string and print it in upperrcase
name='abhinanda'
print(name.upper())
# Out:
# ABHINANDA

# %%
1#store your name in a string and print it in uppercase
name='karthik'
print(name.upper())
# Out:
# KARTHIK

# %%
2#store a statement and print the first and last character
statement="Hello, World!"
print("First character:", statement[0])
print("Last character:", statement[-1])
# Out:
# First character: H
# Last character: !

# %%
3#make a string and print the total number of characters
text="python programing"
print("Total number of characters:", len(text))
# Out:
# Total number of characters: 17

# %%
4#store "hello world" and capitalize the first letter of each word
text="hello world"
print(text.title())
# Out:
# Hello World

# %%
5#replace all space with "-"
sentence="we dont pray for love we just pray to cars"
print(sentence.replace(" ","-"))
# Out:
# we-dont-pray-for-love-we-just-pray-to-cars

# %%
6#how many times repeat 'a' appear in "banana"
text="banana"
print(text.count("a"))
# Out:
# 3

# %%
7#store your favorite movie name and print lowercase
movie="THE PREDATOR"
print(movie.lower())
# Out:
# the predator

# %%
8#check whether "python" exist in the sentence
sentence = "i am learning python today"
print("python" in sentence)
# Out:
# True

# %%
9#delete the extra space from a string
text ="                                                                      hello world                                                                           "
print(text.strip(","))
# Out:
#                                                                       hello world

# %%
10#split fruits into seprate items
fruits="apple,banana,orange"
print(fruits.split(","))
# Out:
# ['apple', 'banana', 'orange']

# %%
21/5/26

# %%
1# create a list of 5 subject names and print the first subject
subjects=["maths","physics","chemistry","english","computer science"]
print(subjects[0])
# Out:
# maths

# %%
2#create a list of numbers and print the last number
number=[10,20,30,40,50]
print (number[-1])
# Out:
# 50

# %%
3# create a list of mobiles brands and add one new brand using a list method
mobiles = ["vivo","iqoo","apple"]
mobiles.append("samsung")
print(mobiles)
# Out:
# ['vivo', 'iqoo', 'apple', 'samsung']

# %%
4#store 5 student names in a list and print the total number of names
student = ["achu","vaishnav","arun","jobin","ajmal"]
print(len(student))
# Out:
# 5

# %%
5#create a list [10,20,30,40]and change 30 to 35
numbers = [10,20,30,40]
numbers[2]=35
print(numbers)
# Out:
# [10, 20, 35, 40]

# %%
6# remove "maths" from the list
subjecst=["science","maths","english"]
subjects.remove("maths")
print(subjects)
# Out:
# ['physics', 'chemistry', 'english', 'computer science']

# %%
7#create a list of numbers and maximum value 
numbers=[20,10,24]
print(max(numbers))
# Out:
# 24

# %%
# 8. store 5 city names in a list and print them in alphabetical order
cities = ["new york","london","paris","tokyo","sydney"]
cities.sort()
print(cities)
# Out:
# ['london', 'new york', 'paris', 'sydney', 'tokyo']

# %%
# 9. combine two lists
list1=[15,10,5]
list2=[27,12,6]
combined = list1 + list2
print(combined)
# Out:
# [15, 10, 5, 27, 12, 6]

# %%
# 10.check whether "bottle" exists in the list
items = ["bottle","phone","pencil","pen"]
if"bottle" in items:
    print("bottle exists in the list")
else:
    print ("bottle does not exist in the list")
# Out:
# bottle exists in the list
