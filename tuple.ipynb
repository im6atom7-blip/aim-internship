# %%
#1 
numbers = (1,2,3,4,5)
print(numbers[0])
# Out:
# 1

# %%
#2
student = ("arun","rahul","akhil")
print(student[-1])
# Out:
# akhil

# %%
#3
t = (10,20,30,40)
print(len(t))
# Out:
# 4

# %%
#4
countries = ("india","usa","canada","japan","china")
print("india" in countries)
# Out:
# True

# %%
#5
nums=(5,10,15,20)
print(max(nums))
# Out:
# 20

# %%
#6
t=(1,5,2,5,3)
print (t.count(5))
# Out:
# 2

# %%
#7
t1=(1,2)
t2=(3,4)
print (t1+t2)
# Out:
# (1, 2, 3, 4)

# %%
#8
animals=("tiger","dog","elephent","cat")
print(sorted(animals))
# Out:
# ['cat', 'dog', 'elephent', 'tiger']

# %%
#9
languages=("python","java","c++")
print(languages.index("java"))
# Out:
# 1

# %%
#10
t=(10,20,30)
print(list(t))
# Out:
# [10, 20, 30]
